# %%
day = input('enter the day')
if day =='monday':
    print('i have to attend my class')
if day == 'wednesday':
    print('i will sleep till 1pm')
if day == 'sunday':
    print('i wont wake up today')
# Out:
# i wont wake up today

# %%
# nested if
value =  int(input('enter amt of money'))
if value > 1000:
    value = value - 500
    if value < 750:
        value = value + 300
print('money available',value)
# Out:
# money available 7999999999999500
